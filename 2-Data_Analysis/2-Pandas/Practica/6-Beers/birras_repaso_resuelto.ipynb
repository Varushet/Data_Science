# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadística
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
beer = pd.read_csv('data/datasets_beers.csv')
beer.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
beer.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='str')

# %%
beer.size
# Out:
# 19280

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
beer.drop('Unnamed: 0', axis=1, inplace=True)
beer
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
print(len(beer.columns))
print(len(beer))
# Out:
# 7
# 2410

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
print(beer.dtypes)
# Out:
# abv           float64
# ibu           float64
# id              int64
# name              str
# style             str
# brewery_id      int64
# ounces        float64
# dtype: object

# %% [markdown]
# ## Ejercicio 6
# Obtén en un nuevo DataFrame un resumen con las principales estadísticas de las columnas numéricas: mean, max, count, cuartiles...

# %%
beer.describe()
# Out:
#                abv          ibu           id   brewery_id       ounces
# count  2348.000000  1405.000000  2410.000000  2410.000000  2410.000000
# mean      0.059773    42.713167  1431.113278   231.749793    13.592241
# std       0.013542    25.954066   752.459975   157.685604     2.352204
# min       0.001000     4.000000     1.000000     0.000000     8.400000
# 25%       0.050000    21.000000   808.250000    93.000000    12.000000
# 50%       0.056000    35.000000  1453.500000   205.000000    12.000000
# 75%       0.067000    64.000000  2075.750000   366.000000    16.000000
# max       0.128000   138.000000  2692.000000   557.000000    32.000000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
conteo = beer['style'].value_counts()
conteo
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# American Malt Liquor                1
# Grisette                            1
# Flanders Oud Bruin                  1
# Braggot                             1
# Low Alcohol Beer                    1
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros desde el décimo hasta el vigésimo
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
beer.loc[10: 20 ,'name':'ounces']
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
beer.loc[10: 20 ,['abv','ibu', 'ounces']]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
# np.array(conteo)
beer.to_numpy()
# Out:
# array([[0.05, nan, 1436, ..., 'American Pale Lager', 408, 12.0],
#        [0.066, nan, 2265, ..., 'American Pale Ale (APA)', 177, 12.0],
#        [0.071, nan, 2264, ..., 'American IPA', 177, 12.0],
#        ...,
#        [0.055, nan, 620, ..., 'Schwarzbier', 424, 12.0],
#        [0.055, 40.0, 145, ..., 'American Pale Ale (APA)', 424, 12.0],
#        [0.052, nan, 84, ..., 'American Amber / Red Ale', 424, 12.0]],
#       shape=(2410, 7), dtype=object)

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
beer['ounces'].values.sum()
# beer['ounces'].isna().unique()
# Out:
# np.float64(32757.3)

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
print("Amargor medio:", beer['ibu'].mean())

print("")

print(beer['ibu'].max())
print(beer.loc[beer['ibu'].idxmax()][['ibu', 'name']])

print("")

print(beer['ibu'].min())
print(beer.loc[beer['ibu'].idxmin()][['ibu', 'name']])
# Out:
# Amargor medio: 42.71316725978647
#
# 138.0
# ibu                         138.0
# name    Bitter Bitch Imperial IPA
# Name: 147, dtype: object
#
# 4.0
# ibu                 4.0
# name    Summer Solstice
# Name: 106, dtype: object

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
print( beer['ibu'].describe())
# Out:
# count    1405.000000
# mean       42.713167
# std        25.954066
# min         4.000000
# 25%        21.000000
# 50%        35.000000
# 75%        64.000000
# max       138.000000
# Name: ibu, dtype: float64

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonamiento mediante un gráfico

# %%
sns.displot(beer["ibu"])

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
sns.displot(beer["abv"])

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
sns.boxplot(beer["abv"])
# Out:
# <Axes: ylabel='abv'>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
beer.groupby('style')['abv'].mean().sort_values(ascending=False).head()
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
# Name: abv, dtype: float64

# %%
beer.groupby('style')['ibu'].mean().sort_values(ascending=False).head()
# Out:
# style
# American Barleywine                   96.00
# American Double / Imperial IPA        93.32
# Russian Imperial Stout                86.50
# American Double / Imperial Pilsner    85.00
# Belgian Strong Dark Ale               72.00
# Name: ibu, dtype: float64

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
cerveceria = pd.read_csv('data/datasets_breweries.csv')
cerveceria
# Out:
#      Unnamed: 0                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra también la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
cerveceria.rename(columns={'Unnamed: 0': 'brewery_id', 'name': 'brewery_name'}, inplace=True)
cerveceria
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
enologic = pd.merge(beer, cerveceria, how='outer')
enologic
# Out:
#         abv   ibu    id                       name                    style  \
# 0     0.045  50.0  2692               Get Together             American IPA
# 1     0.049  26.0  2691              Maggie's Leap       Milk / Sweet Stout
# 2     0.048  19.0  2690                 Wall's End        English Brown Ale
# 3     0.060  38.0  2689                    Pumpion              Pumpkin Ale
# 4     0.060  25.0  2688                 Stronghold          American Porter
# ...     ...   ...   ...                        ...                      ...
# 2405  0.049   NaN    52   Heinnieweisse Weissebier               Hefeweizen
# 2406  0.068   NaN    51            Snapperhead IPA             American IPA
# 2407  0.049   NaN    50          Moo Thunder Stout       Milk / Sweet Stout
# 2408  0.043   NaN    49          Porkslap Pale Ale  American Pale Ale (APA)
# 2409  0.049   NaN    30  Urban Wilderness Pale Ale         English Pale Ale
#
# ...

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
print(len(enologic['state'].unique()))
print(len(enologic['city'].unique()))
print(len(enologic['brewery_id'].unique()))
# Out:
# 51
# 384
# 558

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
enologic.groupby(['state', 'city'])['abv'].agg(['mean', 'median', 'max'])
# Out:
#                       mean  median    max
# state city
# AK    Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
# AL    Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
# WI    Wilson      0.055000  0.0550  0.055
# WV    Lewisburg   0.062000  0.0620  0.067
# WY    Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
enologic['state'] = enologic['state'].str.strip()

# %%
enologic[enologic['state'] == 'IN'].sort_values('ibu', ascending=False).head()
# Out:
#        abv    ibu    id                   name  \
# 145  0.085  115.0  1449  Overlord Imperial IPA
# 166  0.099  115.0  2471       Hopkick Dropkick
# 140  0.060  104.0  1610         Half Cycle IPA
# 203  0.091   91.0   651                   Isis
# 160  0.064   90.0  2610             The Gadget
#
#                               style  brewery_id  ounces  \
# 145  American Double / Imperial IPA          17    16.0
# 166  American Double / Imperial IPA          24    12.0
# 140                    American IPA          16    16.0
# 203  American Double / Imperial IPA          25    16.0
# 160                    American IPA          22    16.0
#
#                  brewery_name           city state
# 145   Tin Man Brewing Company     Evansville    IN
# 166          Burn 'Em Brewing  Michigan City    IN
# 140         Flat 12 Bierwerks   Indianapolis    IN
# 203  Sun King Brewing Company   Indianapolis    IN
# 160     Four Fathers Brewing      Valparaiso    IN

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
enologic.groupby('city')['ibu'].describe()
# Out:
#                 count        mean        std    min     25%    50%     75%  \
# city
# Abingdon          1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs     3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada               0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Afton             4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights    0.0         NaN        NaN    NaN     NaN    NaN     NaN
# ...               ...         ...        ...    ...     ...    ...     ...
# Woodinville       4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester         1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima            2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley           0.0         NaN        NaN    NaN     NaN    NaN     NaN
# York              4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
#                   max
# city
# Abingdon        135.0
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame de todas las cervezas en cuyas cervecerías al menos haya una cerveza con un `abv` mínimo 0.07.

# %%
high_alcohol = enologic[enologic['abv'] > 0.07]['brewery_name'].unique()

resultado = enologic[enologic['brewery_name'].isin(high_alcohol)]
resultado
# Out:
#         abv   ibu    id                                   name  \
# 6     0.080  68.0  2686                         Citra Ass Down
# 7     0.125  80.0  2685                         London Balling
# 8     0.077  25.0  2684                                   35 K
# 9     0.042  42.0  2683                                 A Beer
# 10    0.050  25.0  2682                        Rules are Rules
# ...     ...   ...   ...                                    ...
# 2347  0.062  42.0    28            Tule Duck Red Ale (Current)
# 2348  0.058  35.0    27  Original Orange Blossom Ale (Current)
# 2349  0.052  40.0    26            Black Noddy Lager (Current)
# 2396  0.072   NaN   324                       Wyoming Pale Ale
# 2397  0.050   NaN   323                  Wind River Blonde Ale
#
#                                style  brewery_id  ounces  \
# 6     American Double / Imperial IPA           1    16.0
# 7                 English Barleywine           1    16.0
# ...

# %%
# resultado = enologic[enologic['brewery_id'].isin(
#     enologic[enologic['abv'] >= 0.07]['brewery_id'].unique()
# )]

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
media = enologic['ibu'].mean()
media_estado = enologic.groupby('state')['ibu'].mean()
estado_super = media_estado[media_estado > media].index

final = enologic[enologic['state'].isin(estado_super)]
final
# Out:
#         abv   ibu    id                      name                    style  \
# 0     0.045  50.0  2692              Get Together             American IPA
# 1     0.049  26.0  2691             Maggie's Leap       Milk / Sweet Stout
# 2     0.048  19.0  2690                Wall's End        English Brown Ale
# 3     0.060  38.0  2689                   Pumpion              Pumpkin Ale
# 4     0.060  25.0  2688                Stronghold          American Porter
# ...     ...   ...   ...                       ...                      ...
# 2404  0.055   NaN    98             Pilsner Ukiah          German Pilsener
# 2405  0.049   NaN    52  Heinnieweisse Weissebier               Hefeweizen
# 2406  0.068   NaN    51           Snapperhead IPA             American IPA
# 2407  0.049   NaN    50         Moo Thunder Stout       Milk / Sweet Stout
# 2408  0.043   NaN    49         Porkslap Pale Ale  American Pale Ale (APA)
#
# ...
