# %% [markdown]
# # Ejercicios de Seaborn

# %% [markdown]
# # 1. Importa pandas, pyplot y seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
poke = pd.read_csv('data/Pokemon.csv', index_col=0)
poke
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %% [markdown]
# # 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
poke.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# # 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# ### Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
sns.lmplot(data=poke, x='HP', y='Attack');

# %% [markdown]
# # 6. No queremos ver la línea recta de la regresión lineal.
# ### prueba a añadir fit_reg a falso

# %%
sns.lmplot(data=poke, 
           x='HP',
           y='Attack',
           fit_reg=False);

# %% [markdown]
# # 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# ### Que el hue sea el Stage

# %%
sns.lmplot(data=poke, 
           x='HP',
           y='Attack',
           fit_reg=False,
           hue='Stage');

# %% [markdown]
# # 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(data=poke, 
           x='HP',
           y='Attack',
           fit_reg=False,
           hue='Stage');
plt.xlim(20, 100)
# Out:
# (20.0, 100.0)

# %% [markdown]
# # 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.boxplot(poke)
# Out:
# <Axes: >

# %% [markdown]
# # 10. No nos interesan las columnas Total, Stage ni Legendary
# ### Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
poke.drop(['Total', 'Stage', 'Legendary'], axis=1, inplace=True) #, inplace=True
poke
# Out:
#            Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur    Grass  Poison   45      49       49       65       65
# 2       Ivysaur    Grass  Poison   60      62       63       80       80
# 3      Venusaur    Grass  Poison   80      82       83      100      100
# 4    Charmander     Fire     NaN   39      52       43       60       50
# 5    Charmeleon     Fire     NaN   58      64       58       80       65
# ..          ...      ...     ...  ...     ...      ...      ...      ...
# 147     Dratini   Dragon     NaN   41      64       45       50       50
# 148   Dragonair   Dragon     NaN   61      84       65       70       70
# 149   Dragonite   Dragon  Flying   91     134       95      100      100
# 150      Mewtwo  Psychic     NaN  106     110       90      154       90
# 151         Mew  Psychic     NaN  100     100      100      100      100
#
#      Speed
# #
# 1       45
# 2       60
# 3       80
# 4       65
# 5       80
# ..     ...
# 147     50
# 148     70
# 149     80
# 150    130
# 151    100
#
# [151 rows x 9 columns]

# %% [markdown]
# # 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
len(poke['Type 1'].unique())
# Out:
# 15

# %% [markdown]
# # 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
inicial = poke[poke['Type 1'].isin(['Grass', 'Fire', 'Water'])]
inicial
# Out:
#            Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur  Grass    Poison   45      49       49       65       65
# 2       Ivysaur  Grass    Poison   60      62       63       80       80
# 3      Venusaur  Grass    Poison   80      82       83      100      100
# 4    Charmander   Fire       NaN   39      52       43       60       50
# 5    Charmeleon   Fire       NaN   58      64       58       80       65
# 6     Charizard   Fire    Flying   78      84       78      109       85
# 7      Squirtle  Water       NaN   44      48       65       50       64
# 8     Wartortle  Water       NaN   59      63       80       65       80
# 9     Blastoise  Water       NaN   79      83      100       85      105
# 37       Vulpix   Fire       NaN   38      41       40       50       65
# 38    Ninetales   Fire       NaN   73      76       75       81      100
# 43       Oddish  Grass    Poison   45      50       55       75       65
# 44        Gloom  Grass    Poison   60      65       70       85       75
# 45    Vileplume  Grass    Poison   75      80       85      110       90
# 54      Psyduck  Water       NaN   50      52       48       65       50
# 55      Golduck  Water       NaN   80      82       78       95       80
# 58    Growlithe   Fire       NaN   55      70       45       70       50
# 59     Arcanine   Fire       NaN   90     110       80      100       80
# 60      Poliwag  Water       NaN   40      50       40       40       40
# 61    Poliwhirl  Water       NaN   65      65       65       50       50
# 62    Poliwrath  Water  Fighting   90      95       95       70       90
# 69   Bellsprout  Grass    Poison   50      75       35       70       30
# 70   Weepinbell  Grass    Poison   65      90       50       85       45
# 71   Victreebel  Grass    Poison   80     105       65      100       70
# 72    Tentacool  Water    Poison   40      40       35       50      100
# 73   Tentacruel  Water    Poison   80      70       65       80      120
# 77       Ponyta   Fire       NaN   50      85       55       65       65
# 78     Rapidash   Fire       NaN   65     100       70       80       80
# 79     Slowpoke  Water   Psychic   90      65       65       40       40
# 80      Slowbro  Water   Psychic   95      75      110      100       80
# 86         Seel  Water       NaN   65      45       55       45       70
# 87      Dewgong  Water       Ice   90      70       80       70       95
# 90     Shellder  Water       NaN   30      65      100       45       25
# 91     Cloyster  Water       Ice   50      95      180       85       45
# 98       Krabby  Water       NaN   30     105       90       25       25
# 99      Kingler  Water       NaN   55     130      115       50       50
# 102   Exeggcute  Grass   Psychic   60      40       80       60       45
# 103   Exeggutor  Grass   Psychic   95      95       85      125       65
# 114     Tangela  Grass       NaN   65      55      115      100       40
# 116      Horsea  Water       NaN   30      40       70       70       25
# 117      Seadra  Water       NaN   55      65       95       95       45
# 118     Goldeen  Water       NaN   45      67       60       35       50
# 119     Seaking  Water       NaN   80      92       65       65       80
# 120      Staryu  Water       NaN   30      45       55       70       55
# 121     Starmie  Water   Psychic   60      75       85      100       85
# 126      Magmar   Fire       NaN   65      95       57      100       85
# 129    Magikarp  Water       NaN   20      10       55       15       20
# 130    Gyarados  Water    Flying   95     125       79       60      100
# 131      Lapras  Water       Ice  130      85       80       85       95
# 134    Vaporeon  Water       NaN  130      65       60      110       95
# 136     Flareon   Fire       NaN   65     130       60       95      110
# 146     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# #
# 1       45
# 2       60
# 3       80
# 4       65
# 5       80
# 6      100
# 7       43
# 8       58
# 9       78
# 37      65
# 38     100
# 43      30
# 44      40
# 45      50
# 54      55
# 55      85
# 58      60
# 59      95
# 60      90
# 61      90
# 62      70
# 69      40
# 70      55
# 71      70
# 72      70
# 73     100
# 77      90
# 78     105
# 79      15
# 80      30
# 86      45
# 87      70
# 90      40
# 91      70
# 98      50
# 99      75
# 102     40
# 103     55
# 114     60
# 116     60
# 117     85
# 118     63
# 119     68
# 120     85
# 121    115
# 126     93
# 129     80
# 130     81
# 131     60
# 134     65
# 136     65
# 146     90

# %% [markdown]
# # 13. Usa un estilo 'whitegrid'

# %%
sns.set_style('whitegrid')
sns.lmplot(data=inicial, 
           x='HP',
           y='Attack',
           fit_reg=False);
plt.xlim(20, 100)
# Out:
# (20.0, 100.0)

# %% [markdown]
# # 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

# %%
sns.violinplot(data=inicial);

# %% [markdown]
# # 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores_ini = ['#78c850', '#f08030', '#6890f0']

# %% [markdown]
# # 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(data=inicial,
               x='Type 1',
               y='Defense',
               palette=colores_ini);
# Out:
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\875208425.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=inicial,

# %% [markdown]
# # 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# ### Para ver esto, usamos el swarmplot.
# ### Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(poke)
# Out:
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: >
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 13.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# ### Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# ### Pon un título con pyplot (como siempre)

# %%
sns.violinplot(data=inicial,
               x='Type 1',
               y='Defense',
               palette=colores_ini,
               inner=None,);
sns.swarmplot(data=inicial,
              x='Type 1',
              y='Defense',
              alpha=0.9);
plt.title('Distribución del atributo Defensa de los pokemones del tipo de los pokemones seleccionables iniciales');
# Out:
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\3584744134.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=inicial,

# %% [markdown]
# # 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# ### Dado un DataFrame, melt recibe varios parámetros:
# ### * qué columnas del DataFrame se quedan igual
# ### * qué nombres de columnas del dataframe pasan a ser una columna nueva
# ### * cómo queremos llamar esas nuevas columnas
#
# ### Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
inicial.head()
# Out:
#          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3    Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Charmander   Fire     NaN  39      52       43       60       50     65
# 5  Charmeleon   Fire     NaN  58      64       58       80       65     80

# %% [markdown]
# # 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# ### Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# ### Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
fusion = inicial.melt(id_vars=['Name', 'Type 1'], 
                         value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'], 
                         var_name='Stat', 
                         value_name='Value')
fusion
# Out:
#            Name Type 1   Stat  Value
# 0     Bulbasaur  Grass     HP     45
# 1       Ivysaur  Grass     HP     60
# 2      Venusaur  Grass     HP     80
# 3    Charmander   Fire     HP     39
# 4    Charmeleon   Fire     HP     58
# ..          ...    ...    ...    ...
# 307    Gyarados  Water  Speed     81
# 308      Lapras  Water  Speed     60
# 309    Vaporeon  Water  Speed     65
# 310     Flareon   Fire  Speed     65
# 311     Moltres   Fire  Speed     90
#
# [312 rows x 4 columns]

# %% [markdown]
# # 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.swarmplot(data=fusion, 
              x='Stat', 
              y='Value',
              palette=colores_ini)
plt.show()
# Out:
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\2314849823.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=fusion,
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\2314849823.py:1: UserWarning:
# The palette list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.swarmplot(data=fusion,

# %% [markdown]
# # 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# ### En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# ### Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# ## Usando plt
# ### fija el límite del eje Y entre 0 y 200
# ### fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# ### Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
sns.swarmplot(data=fusion, 
              x='Stat', 
              y='Value',
              dodge=True,
              palette=colores_ini);
plt.ylim(0, 200)
plt.legend(bbox_to_anchor=(1, 1), loc=2);
# Out:
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\828999217.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=fusion,
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\828999217.py:1: UserWarning:
# The palette list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.swarmplot(data=fusion,
# C:\Users\detla\AppData\Local\Temp\ipykernel_20324\828999217.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1, 1), loc=2);

# %% [markdown]
# # 23. Mapas de calor
# ### Calcula las correlaciones del primer DataFrame original df
# ### Pista: las correlaciones se calculan con el método corr()
# ### Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
correlacion = poke.iloc[:, 4:].corr()

plt.figure(figsize=(10, 8))  # Era (10:8), debe ser (10, 8)
sns.heatmap(correlacion,      # Falta pasar el dataframe de correlación
            annot=True,        # Muestra los valores numéricos
            cmap='coolwarm',   # Mapa de colores
            fmt='.2f',         # Formato de 2 decimales
            linewidths=0.5)    # Líneas entre celdas
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# ### ¿la correlación entre qué valores se encuentra?
# ### la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# ### Encuentra dos variables que veas que están fuertemente relacionadas según la correlación

# %% [markdown]
# no hay ninguna por encima de 0.5
# que es perfecta
# ninguna...

# %% [markdown]
# # 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.histplot(data=poke, 
             x='Defense', 
             kde=True);

# %% [markdown]
# # 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# ### Usa un sns.countplot
# ### Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(data=poke, x='Type 1')
plt.xticks(rotation=180);

# %% [markdown]
# # 26. Usa catplot con el DataFrame original.
# ### Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios y divide los colores según el Type 2

# %%
sns.catplot(data=poke, x='Type 1', y='Defense', hue='Type 2', col='Legendary', kind='violin')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 sns.catplot(data=poke, x='Type 1', y='Defense', hue='Type 2', col='Legendary', kind='violin')
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2782, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779     elif x is not None and y is not None:
#    2780         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    2785         x=x, y=y, hue=hue, row=row, col=col, units=units, weight=weights
#    2786     ),
#    2787     order=order,
#    2788     orient=orient,
#    2789     # Handle special backwards compatibility where pointplot originally
#    2790     # did *not* default to multi-colored unless a palette was specified.
#    2791     color="C0" if kind == "point" and palette is None and color is None else color,
#    2792     legend=legend,
#    2793 )
#    2795 for var in ["row", "col"]:
#    2796     # Handle faceting variables that lack name information
#    2797     if var in p.variables and p.variables[var] is None:
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)     64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)     76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Legendary` for `col`. An entry with this name does not appear in `data`.

# %% [markdown]
# # 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# ### Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(data=poke, x='Attack', y='Defense')
plt.show()

# Un bin 2D donde caen muchos puntos es alrededor de Attack=50-70, Defense=50-70

# %% [markdown]
# # 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot(data=poke, x='Attack', y='Defense')
