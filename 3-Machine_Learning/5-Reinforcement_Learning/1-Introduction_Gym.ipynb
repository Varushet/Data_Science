# %% [markdown]
# ## Intro Aprendizaje por Refuerzo

# %% [markdown]
# Considera el escenario de enseñarle nuevos trucos a un perro. El perro no entiende nuestro lenguaje, así que no podemos decirle qué hacer. En cambio, seguimos una estrategia diferente. Emulamos una situación (o una señal), y el perro intenta responder de muchas maneras diferentes. Si la respuesta del perro es la deseada, lo recompensamos con golosinas. Ahora, adivina qué, la próxima vez que el perro se enfrenta a la misma situación, ejecuta una acción similar con aún más entusiasmo esperando más comida. Esto es como aprender "qué hacer" a partir de experiencias positivas. De manera similar, los perros tienden a aprender qué no hacer cuando se enfrentan a experiencias negativas.

# %% [markdown]
# ## Entendiendo cómo funciona el Aprendizaje por Refuerzo
#
# En un sentido más amplio, así es como funciona el Aprendizaje por Refuerzo:
#
# * Tu perro es un "agente" que está expuesto al entorno. El entorno podría ser tu casa, contigo.
# * Las situaciones que encuentran son análogas a un estado. Un ejemplo de un estado podría ser tu perro de pie y tú usando una palabra específica con cierto tono en tu sala de estar.
# * Nuestros agentes reaccionan realizando una acción para pasar de un "estado" a otro "estado"; por ejemplo, tu perro pasa de estar de pie a sentarse.
# * Después de la transición, pueden recibir una recompensa o una penalización a cambio. ¡Les das una golosina! O un "No" como penalización.
# * La política es la estrategia de elegir una acción dada un estado en espera de mejores resultados.

# %% [markdown]
# El Aprendizaje por Refuerzo se encuentra entre el espectro del Aprendizaje Supervisado y el No Supervisado, y hay algunas cosas importantes que tener en cuenta:
#
# #### No siempre es beneficioso ser codicioso
#
# **Ser codicioso no siempre funciona:**
#
# * Hay cosas que son fáciles de hacer para obtener una gratificación instantánea, y hay cosas que proporcionan recompensas a largo plazo. El objetivo no es ser codicioso buscando las recompensas inmediatas, sino optimizar las recompensas máximas durante todo el entrenamiento.
#
# #### La secuencia importa en el Aprendizaje por Refuerzo
#
# **La secuencia importa en el Aprendizaje por Refuerzo:**
#
# * La recompensa del agente no solo depende del estado actual, sino de toda la historia de estados. A diferencia del aprendizaje supervisado y no supervisado, el tiempo es importante aquí.

# %% [markdown]
# ## El proceso

# %% [markdown]
# <img src="./img/Reinforcement-Learning-Animation.gif" alt="drawing" width="650"/>

# %% [markdown]
# En cierto sentido, el Aprendizaje por Refuerzo es la ciencia de tomar decisiones óptimas utilizando experiencias. Desglosándolo, el proceso de Aprendizaje por Refuerzo involucra estos pasos simples:
#
# 1. Observación del entorno.
# 2. Decidir cómo actuar utilizando alguna estrategia.
# 3. Actuar en consecuencia.
# 4. Recibir una recompensa o penalización.
# 5. Aprender de las experiencias y refinar nuestra estrategia.
# 6. Iterar hasta encontrar una estrategia óptima.
#
# Ahora vamos a entender el Aprendizaje por Refuerzo desarrollando un agente para aprender a jugar un juego automáticamente por sí mismo.

# %% [markdown]
# ## Comenzando con Gym
#
# Gym es un conjunto de herramientas para desarrollar y comparar algoritmos de aprendizaje por refuerzo. No hace suposiciones sobre la estructura de tu agente y es compatible con cualquier biblioteca de cálculo numérico, como TensorFlow o Theano.
#
# La biblioteca Gym es una colección de problemas de prueba, o entornos, que puedes usar para desarrollar tus algoritmos de aprendizaje por refuerzo. Estos entornos tienen una interfaz compartida, lo que te permite escribir algoritmos generales.

# %%
# %pip install gymnasium[classic_control]
# %pip install pygame
# Out:
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gymnasium[classic_control]) (2.3.5)
# Collecting cloudpickle>=1.2.0 (from gymnasium[classic_control])
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\Users\detla\AppData\Roaming\Python\Python311\site-packages (from gymnasium[classic_control]) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[classic_control])
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Collecting pygame-ce>=2.1.3 (from gymnasium[classic_control])
#   Downloading pygame_ce-2.5.7-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 953.9/953.9 kB 14.7 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Downloading pygame_ce-2.5.7-cp311-cp311-win_amd64.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------- ----------------- 5.8/10.4 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 28.3 MB/s  0:00:00
# Installing collected packages: farama-notifications, pygame-ce, cloudpickle, gymnasium
#
#    ---------- ----------------------------- 1/4 [pygame-ce]
#    ---------- ----------------------------- 1/4 [pygame-ce]
#    ---------- ----------------------------- 1/4 [pygame-ce]
#    ---------- ----------------------------- 1/4 [pygame-ce]
#    ---------- ----------------------------- 1/4 [pygame-ce]
#    -------------------- ------------------- 2/4 [cloudpickle]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ---------------------------------------- 4/4 [gymnasium]
#
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.6 gymnasium-1.3.0 pygame-ce-2.5.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/10.6 MB 30.2 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 31.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 27.6 MB/s  0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!pip install numpy==1.23.5

# %% [markdown]
# ## Entornos
#
# Aquí tienes un ejemplo mínimo para comenzar a ejecutar algo. Esto ejecutará una instancia del entorno CartPole-v0 durante 1000 pasos de tiempo, representando el entorno en cada paso.

# %% [markdown]
#  Consiste en equilibrar un poste (péndulo) montado en la parte superior de un carrito móvil:
#  * El **objetivo** es mantener el poste en posición vertical mientras el carrito se mueve hacia adelante y hacia atrás en una pista.
#  * El **agente** (o jugador) tiene dos acciones disponibles en cada paso de tiempo: empujar el carrito hacia la izquierda o hacia la derecha.
#  * El **desafío** radica en tomar decisiones adecuadas para evitar que el poste caiga mientras se mueve el carrito.
#
#  Este problema es un ejemplo comúnmente utilizado para probar algoritmos de aprendizaje por refuerzo debido a su simplicidad y naturaleza desafiante.

# %% [markdown]
# https://gymnasium.farama.org/api/env/

# %%
import gymnasium as gym
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np

# %% [markdown]
# Crea un entorno de simulación llamado MountainCar-v0.
# Este es un entorno clásico en gym en el que un coche debe moverse hacia arriba de una colina empinada.
# El objetivo es aplicar fuerza en las direcciones izquierda o derecha para ganar impulso suficiente y alcanzar la cima.

# %%
env = gym.make('MountainCar-v0')

# %% [markdown]
# Reinicia el entorno a su estado inicial.
# Esto es útil para comenzar una nueva simulación. Devuelve el estado inicial del entorno.

# %%
env.reset()
# Out:
# (array([-0.5345881,  0.       ], dtype=float32), {})

# %% [markdown]
# A continuación: se ejecuta un bucle con 300 pasos dentro del entorno.

# %% [markdown]
# ``env.render()`` dibuja el entorno en una ventana gráfica para que puedas visualizar lo que está sucediendo (por ejemplo, el carro moviéndose).

# %% [markdown]
# ``env.action_space.sample()``
# Toma una acción aleatoria en el espacio de acciones del entorno. En este caso, las acciones posibles son:
#
# * 0: Aplicar fuerza hacia la izquierda.
# * 1: No aplicar fuerza.
# * 2: Aplicar fuerza hacia la derecha.

# %%
#for i in range(300):
#    env.render()
#    time.sleep(0.1)
#    env.step(env.action_space.sample()) # take a random action
#env.close()

# %%
#numpy.__version__

# %%
import gymnasium as gym
import warnings
import numpy

warnings.filterwarnings("ignore")

# Crear el entorno
env = gym.make('MountainCar-v0')
env.reset()

# Loop para ejecutar pasos en el entorno
for i in range(300):
    env.render()  # Renderizar el entorno
    env.step(env.action_space.sample())  # Tomar una acción aleatoria

env.close()

# %%
#numpy.__version__

# %% [markdown]
# Normalmente, terminaremos la simulación antes de que el carrito-péndulo tenga permitido salir de la pantalla. Más sobre eso después. Por ahora, por favor ignora la advertencia sobre llamar a `step()` aunque este entorno ya haya devuelto `done = True`.
#
# Si deseas ver otros entornos en acción, intenta reemplazar `CartPole-v0` arriba con algo como `MountainCar-v0`, `MsPacman-v0` (requiere la dependencia de Atari), o `Hopper-v1` (requiere las dependencias de MuJoCo). Todos los entornos descienden de la clase base `Env`.
#
# Ten en cuenta que si te faltan dependencias, deberías recibir un mensaje de error útil que te diga qué te falta. (Avísanos si alguna dependencia te causa problemas sin una instrucción clara para solucionarlo). Instalar una dependencia faltante generalmente es bastante simple. También necesitarás una licencia de MuJoCo para `Hopper-v1`.

# %% [markdown]
# ## Observaciones
#
# Si queremos hacer algo mejor que tomar acciones aleatorias en cada paso, probablemente sería bueno saber realmente qué están haciendo nuestras acciones en el entorno.
#
# La función `step` del entorno devuelve exactamente lo que necesitamos. De hecho, `step` devuelve cuatro valores. Estos son:
#
# * `observation` (object): un objeto específico del entorno que representa tu observación del entorno. Por ejemplo, datos de píxeles de una cámara, ángulos de articulación y velocidades de articulación de un robot, o el estado del tablero en un juego de mesa.
# * `reward` (float): cantidad de recompensa lograda por la acción anterior. La escala varía entre entornos, pero el objetivo es siempre aumentar tu recompensa total.
# * `done` (bool): si es hora de restablecer el entorno nuevamente. La mayoría (pero no todos) de las tareas están divididas en episodios bien definidos, y `done` siendo True indica que el episodio ha terminado. (Por ejemplo, tal vez el poste se inclinó demasiado, o perdiste tu última vida).
# * `truncated` (bool): True si el episodio se trunca debido a un límite de tiempo o una razón que no está definida.
# * `info` (dict): información de diagnóstico útil para la depuración. A veces puede ser útil para el aprendizaje (por ejemplo, podría contener las probabilidades crudas detrás del último cambio de estado del entorno). Sin embargo, no se permite usar esto para el aprendizaje en las evaluaciones oficiales de tu agente.
#
# Esto es simplemente una implementación del clásico "bucle agente-entorno". En cada paso de tiempo, el agente elige una acción, y el entorno devuelve una observación y una recompensa.

# %%
env = gym.make('MountainCar-v0')

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## Espacio de Acciones
#
# Hay 3 acciones discretas determinísticas:
#
# | Num | Observación          | Valor | Unidad       |
# |-----|----------------------|-------|--------------|
# | 0   | Acelerar a la izquierda | Inf   | posición (m) |
# | 1   | No acelerar              | Inf   | posición (m) |
# | 2   | Acelerar a la derecha    | Inf   | posición (m) |

# %%
# env = gym.make('MountainCar-v0', render_mode='human')
print(env.observation_space.shape)
# Out:
# (2,)

# %% [markdown]
# ## Espacio de Observación
#
# La observación es un ndarray con forma (2,), donde los elementos corresponden a lo siguiente:
#
# | Num | Observación                    | Mínimo | Máximo | Unidad        |
# |-----|--------------------------------|--------|--------|---------------|
# | 0   | posición del coche a lo largo del eje x | -Inf   | Inf    | posición (m) |
# | 1   | velocidad del coche             | -Inf   | Inf    | velocidad (m) |

# %%
import numpy as np
np.random.choice(np.array([1,2,3]))
# Out:
# np.int64(3)

# %%
# import gym
env = gym.make('MountainCar-v0', render_mode='human')
for i_episode in range(5):
    # Reset del entorno
    print("Intento", i_episode)
    observation = env.reset()
    for t in range(10000):
        if t % 10 == 0:
            print("Accion", t)
            print("Observación", observation)
        # Visualizar ejercicio
        env.render()
        # Print del estado
        # print(observation)
        # Guarda en la variable action una de las acciones posibles elegida al azar
        action = env.action_space.sample()
        # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
        # que nos indica que ha alcanzado su objetivo e info debug
        observation, reward, done, truncated, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Intento 0
# Accion 0
# Observación (array([-0.41632795,  0.        ], dtype=float32), {})
# Accion 10
# Observación [-0.4465037  -0.00537717]
# Accion 20
# Observación [-0.532852   -0.00933022]
# Accion 30
# Observación [-0.57818824 -0.00160489]
# Accion 40
# Observación [-0.58234     0.00061183]
# Accion 50
# Observación [-0.5186257   0.00828852]
# Accion 60
# Observación [-0.445075    0.00519412]
# Accion 70
# Observación [-0.43527305 -0.00234118]
# Accion 80
# Observación [-0.4941823  -0.00721167]
# Accion 90
# Observación [-0.54534215 -0.00557173]
# Accion 100
# Observación [-5.6815940e-01  2.3604918e-04]
# Accion 110
# Observación [-5.730672e-01 -3.002839e-04]
# Accion 120
# Observación [-0.5541662  0.005147 ]
# Accion 130
# Observación [-0.50621355  0.00599594]
# Accion 140
# Observación [-0.44894978  0.00365827]
# Accion 150
# Observación [-0.44585496 -0.00333531]
# Accion 160
# Observación [-0.51328623 -0.00592892]
# Accion 170
# Observación [-0.5715994  -0.00350894]
# Accion 180
# Observación [-0.5808159   0.00280051]
# Accion 190
# Observación [-0.5372257   0.00469575]
# Accion 200
# Observación [-0.49698704  0.00533069]
# Accion 210
# Observación [-0.44093767  0.00538212]
# Accion 220
# Observación [-0.43094802 -0.00247021]
# Accion 230
# Observación [-0.4912322  -0.00875776]
# Accion 240
# Observación [-0.5730762 -0.0072515]
# Accion 250
# Observación [-6.0460746e-01 -1.3779053e-04]
# Accion 260
# Observación [-0.54850155  0.00844307]
# Accion 270
# Observación [-0.4789492   0.00483459]
# Accion 280
# Observación [-0.4398338   0.00316831]
# Accion 290
# Observación [-0.44680217 -0.00531123]
# Accion 300
# Observación [-0.53739876 -0.01021224]
# Accion 310
# Observación [-0.6238203  -0.00820375]
# Accion 320
# Observación [-0.6758639  -0.00070667]
# Accion 330
# Observación [-0.6276384  0.0084358]
# Accion 340
# Observación [-0.51851094  0.00838362]
# Accion 350
# Observación [-0.44522476  0.00422985]
# Accion 360
# Observación [-0.4520717  -0.00375447]
# Accion 370
# Observación [-0.5307813 -0.0087321]
# Accion 380
# Observación [-0.59818035 -0.00461046]
# Accion 390
# Observación [-6.1999595e-01  7.1710776e-05]
# Accion 400
# Observación [-0.5870925   0.00549142]
# Accion 410
# Observación [-0.5108983   0.00778453]
# Accion 420
# Observación [-0.44618303  0.00428502]
# Accion 430
# Observación [-4.1850254e-01  3.7025477e-04]
# Accion 440
# Observación [-0.4492841  -0.00570296]
# Accion 450
# Observación [-0.51211774 -0.00512309]
# Accion 460
# Observación [-0.5485865  -0.00237395]
# Accion 470
# Observación [-0.56247205 -0.00104562]
# Accion 480
# Observación [-0.5446985   0.00235067]
# Accion 490
# Observación [-0.52786434  0.00150258]
# Accion 500
# Observación [-0.52307     0.00160798]
# Accion 510
# Observación [-0.5257361  -0.00373113]
# Accion 520
# Observación [-0.56834304 -0.0050572 ]
# Accion 530
# Observación [-5.9617811e-01 -4.0474476e-04]
# Accion 540
# Observación [-0.5754435   0.00463007]
# Accion 550
# Observación [-0.5073805   0.00717997]
# Accion 560
# Observación [-4.8089808e-01 -4.0905052e-04]
# Accion 570
# Observación [-0.4958076  -0.00227827]
# Accion 580
# Observación [-0.50801027  0.00135893]
# Accion 590
# Observación [-0.5056724  -0.00202028]
# Accion 600
# Observación [-0.5289911 -0.0014912]
# Accion 610
# Observación [-5.5248553e-01 -1.9231132e-04]
# Accion 620
# Observación [-0.5362457   0.00488485]
# Accion 630
# Observación [-0.5017924   0.00361107]
# Accion 640
# Observación [-0.49142912 -0.00186636]
# Accion 650
# Observación [-0.5015618  -0.00204208]
# Accion 660
# Observación [-0.52610755 -0.00185759]
# Accion 670
# Observación [-0.53620803 -0.00232252]
# Accion 680
# Observación [-0.53844583  0.00099479]
# Accion 690
# Observación [-0.52956986  0.00097107]
# Accion 700
# Observación [-0.5095171   0.00384329]
# Accion 710
# Observación [-0.49508524 -0.003218  ]
# Accion 720
# Observación [-0.54846513 -0.0089853 ]
# Accion 730
# Observación [-0.59689784 -0.00430573]
# Accion 740
# Observación [-0.60456574  0.00068158]
# Accion 750
# Observación [-0.54596156  0.00827388]
# Accion 760
# Observación [-0.48613063  0.00359006]
# Accion 770
# Observación [-4.7174421e-01  5.5477816e-05]
# Accion 780
# Observación [-0.48004913 -0.00164793]
# Accion 790
# Observación [-0.49687728 -0.00346775]
# Accion 800
# Observación [-0.520629   -0.00269129]
# Accion 810
# Observación [-0.54252625 -0.00228238]
# Accion 820
# Observación [-0.55073446  0.00057221]
# Accion 830
# Observación [-0.54172367  0.00237036]
# Accion 840
# Observación [-0.5174469   0.00089188]
# Accion 850
# Observación [-0.5199116  -0.00272984]
# Accion 860
# Observación [-0.54544765 -0.00331458]
# Accion 870
# Observación [-5.5534661e-01 -1.4483457e-04]
# Accion 880
# Observación [-0.5725153  -0.00236156]
# Accion 890
# Observación [-5.811604e-01 -2.549339e-04]
# Accion 900
# Observación [-0.56415075  0.00265543]
# Accion 910
# Observación [-0.5433884   0.00201363]
# Accion 920
# Observación [-0.48934808  0.00694266]
# Accion 930
# Observación [-0.43860465  0.00341407]
# Accion 940
# Observación [-0.44993743 -0.00394086]
# Accion 950
# Observación [-0.53199816 -0.00999452]
# Accion 960
# Observación [-0.62031686 -0.00734485]
# Accion 970
# Observación [-0.6350726   0.00298855]
# Accion 980
# Observación [-0.58470106  0.00562911]
# Accion 990
# Observación [-0.5276899   0.00743377]
# Accion 1000
# Observación [-0.46016335  0.00522624]
# Accion 1010
# Observación [-0.42673337  0.00206159]
# Accion 1020
# Observación [-0.456467   -0.00338009]
# Accion 1030
# Observación [-0.51961774 -0.00735488]
# Accion 1040
# Observación [-0.58182955 -0.00428491]
# Accion 1050
# Observación [-0.60605145 -0.00078822]
# Accion 1060
# Observación [-0.572223    0.00543741]
# Accion 1070
# Observación [-0.4930324   0.00969253]
# Accion 1080
# Observación [-0.4262352   0.00149466]
# Accion 1090
# Observación [-0.43415898 -0.00389747]
# Accion 1100
# Observación [-0.50407535 -0.00959078]
# Accion 1110
# Observación [-0.6033016  -0.00879641]
# Accion 1120
# Observación [-0.62191683  0.00446035]
# Accion 1130
# Observación [-0.5428018   0.00949124]
# Accion 1140
# Observación [-0.45057467  0.00552245]
# Accion 1150
# Observación [-0.4089606   0.00255971]
# Accion 1160
# Observación [-0.46135938 -0.0109304 ]
# Accion 1170
# Observación [-0.58963794 -0.01227719]
# Accion 1180
# Observación [-0.6816504  -0.00483139]
# Accion 1190
# Observación [-0.6669888   0.00671121]
# Accion 1200
# Observación [-0.565938    0.01337491]
# Accion 1210
# Observación [-0.44556487  0.00928805]
# Accion 1220
# Observación [-0.41944337 -0.00309604]
# Accion 1230
# Observación [-0.47618023 -0.00939109]
# Accion 1240
# Observación [-0.5877182  -0.01132413]
# Accion 1250
# Observación [-0.64393395 -0.00111148]
# Accion 1260
# Observación [-0.60325617  0.00576949]
# Accion 1270
# Observación [-0.52808386  0.00718715]
# Accion 1280
# Observación [-0.455778   0.0081943]
# Accion 1290
# Observación [-0.3984036  0.0028793]
# Accion 1300
# Observación [-0.4042907  -0.00449114]
# Accion 1310
# Observación [-0.49763572 -0.01370689]
# Accion 1320
# Observación [-0.6375365  -0.01283003]
# Accion 1330
# Observación [-6.9307005e-01 -5.6413097e-05]
# Accion 1340
# Observación [-0.6257807   0.01070977]
# Accion 1350
# Observación [-0.48035836  0.01588064]
# Accion 1360
# Observación [-0.3662867   0.00850541]
# Accion 1370
# Observación [-0.35914272 -0.00700478]
# Accion 1380
# Observación [-0.48396292 -0.0154993 ]
# Accion 1390
# Observación [-0.6265981  -0.01245266]
# Accion 1400
# Observación [-0.69008017 -0.002298  ]
# Accion 1410
# Observación [-0.65010333  0.0079604 ]
# Accion 1420
# Observación [-0.5195676   0.01424023]
# Accion 1430
# Observación [-0.38823825  0.0092694 ]
# Accion 1440
# Observación [-3.580971e-01 -6.793023e-05]
# Accion 1450
# Observación [-0.42105788 -0.01180618]
# Accion 1460
# Observación [-0.5700453  -0.01464294]
# Accion 1470
# Observación [-0.6895937  -0.00878945]
# Accion 1480
# Observación [-0.7075774   0.00536431]
# Accion 1490
# Observación [-0.57525015  0.01604239]
# Accion 1500
# Observación [-0.40388522  0.01488404]
# Accion 1510
# Observación [-0.3301262   0.00115837]
# Accion 1520
# Observación [-0.39397156 -0.0124434 ]
# Accion 1530
# Observación [-0.51951516 -0.01059349]
# Accion 1540
# Observación [-0.61868566 -0.00730322]
# Accion 1550
# Observación [-0.6601116   0.00170167]
# Accion 1560
# Observación [-0.5825552   0.00951824]
# Accion 1570
# Observación [-0.47138172  0.01125395]
# Accion 1580
# Observación [-0.3905582   0.00197122]
# Accion 1590
# Observación [-0.42367372 -0.00612435]
# Accion 1600
# Observación [-0.5452028  -0.01596084]
# Accion 1610
# Observación [-0.68375874 -0.01149483]
# Accion 1620
# Observación [-0.6914726   0.00725472]
# Accion 1630
# Observación [-0.54079556  0.01935885]
# Accion 1640
# Observación [-0.3557386   0.01631935]
# Accion 1650
# Observación [-0.26153174  0.00404433]
# Accion 1660
# Observación [-0.30366302 -0.01344531]
# Accion 1670
# Observación [-0.51444376 -0.02417203]
# Accion 1680
# Observación [-0.724146   -0.01648969]
# Accion 1690
# Observación [-0.77539074  0.00396818]
# Accion 1700
# Observación [-0.6311875   0.01882225]
# Accion 1710
# Observación [-0.4485968   0.01868331]
# Accion 1720
# Observación [-0.31861526  0.007405  ]
# Accion 1730
# Observación [-0.30845007 -0.00583708]
# Accion 1740
# Observación [-0.4565118  -0.02028294]
# Accion 1750
# Observación [-0.68645895 -0.02052638]
# Accion 1760
# Observación [-0.8183907 -0.0055288]
# Accion 1770
# Observación [-0.7744966  0.0135491]
# Accion 1780
# Observación [-0.54773813  0.02784883]
# Accion 1790
# Observación [-0.30292955  0.01903122]
# Accion 1800
# Observación [-0.20789193  0.00054082]
# Accion 1810
# Observación [-0.34108448 -0.02270779]
# Accion 1820
# Observación [-0.6017077  -0.02558818]
# Accion 1830
# Observación [-0.78374773 -0.01037155]
# Accion 1840
# Observación [-0.7948813   0.00724486]
# Accion 1850
# Observación [-0.60556364  0.0251286 ]
# Accion 1860
# Observación [-0.3745205   0.02019078]
# Accion 1870
# Observación [-0.24437748  0.00479118]
# Accion 1880
# Observación [-0.2990252  -0.01110543]
# Accion 1890
# Observación [-0.47829887 -0.02312292]
# Accion 1900
# Observación [-0.68669736 -0.01615987]
# Accion 1910
# Observación [-7.579129e-01 -5.426071e-04]
# Accion 1920
# Observación [-0.6899298   0.01463862]
# Accion 1930
# Observación [-0.49353188  0.02069198]
# Accion 1940
# Observación [-0.31666702  0.01541862]
# Accion 1950
# Observación [-0.26456064 -0.00228694]
# Accion 1960
# Observación [-0.39248487 -0.02139728]
# Accion 1970
# Observación [-0.6357053  -0.02409119]
# Accion 1980
# Observación [-0.8049982  -0.01016014]
# Accion 1990
# Observación [-0.7906995   0.01107083]
# Accion 2000
# Observación [-0.6060604   0.02466105]
# Accion 2010
# Observación [-0.3687912   0.02046417]
# Accion 2020
# Observación [-0.26791105  0.00150197]
# Accion 2030
# Observación [-0.31488734 -0.0122745 ]
# Accion 2040
# Observación [-0.50104547 -0.02189299]
# Accion 2050
# Observación [-0.6848949  -0.01407613]
# Accion 2060
# Observación [-7.5082266e-01  2.0582606e-04]
# Accion 2070
# Observación [-0.70224655  0.01120974]
# Accion 2080
# Observación [-0.53508884  0.02030213]
# Accion 2090
# Observación [-0.3416397   0.01539852]
# Accion 2100
# Observación [-0.26982346 -0.00145216]
# Accion 2110
# Observación [-0.36182362 -0.01596662]
# Accion 2120
# Observación [-0.54878443 -0.02000057]
# Accion 2130
# Observación [-0.6976057  -0.00844908]
# Accion 2140
# Observación [-0.71810997  0.00427105]
# Accion 2150
# Observación [-0.6055958   0.01632406]
# Accion 2160
# Observación [-0.4211845   0.01625063]
# Accion 2170
# Observación [-0.2967443   0.00720307]
# Accion 2180
# Observación [-0.2936094  -0.00723951]
# Accion 2190
# Observación [-0.45422733 -0.02119075]
# Accion 2200
# Observación [-0.6591113  -0.01842655]
# Accion 2210
# Observación [-0.77262306 -0.00459371]
# Accion 2220
# Observación [-0.7550536   0.00851354]
# Accion 2230
# Observación [-0.61901534  0.01703056]
# Accion 2240
# Observación [-0.44415104  0.01726529]
# Accion 2250
# Observación [-0.33640248  0.00416771]
# Accion 2260
# Observación [-0.34439364 -0.00760276]
# Accion 2270
# Observación [-0.49739254 -0.02040492]
# Accion 2280
# Observación [-0.7107066  -0.01916583]
# Accion 2290
# Observación [-0.8121818  -0.00138153]
# Accion 2300
# Observación [-0.7296842   0.01644604]
# Accion 2310
# Observación [-0.49502552  0.02738911]
# Accion 2320
# Observación [-0.2647539   0.01639109]
# Accion 2330
# Observación [-0.19294305 -0.00146717]
# Accion 2340
# Observación [-0.31704372 -0.02051461]
# Accion 2350
# Observación [-0.5841502  -0.02930114]
# Accion 2360
# Observación [-0.80387014 -0.01318004]
# Accion 2370
# Observación [-0.8142449   0.00849909]
# Accion 2380
# Observación [-0.641237    0.02189359]
# Accion 2390
# Observación [-0.39284924  0.02225238]
# Accion 2400
# Observación [-0.23818795  0.00970968]
# Accion 2410
# Observación [-0.25217304 -0.01277077]
# Accion 2420
# Observación [-0.45446748 -0.02407569]
# Accion 2430
# Observación [-0.6980826  -0.02296704]
# Accion 2440
# Observación [-0.8416901  -0.00585352]
# Accion 2450
# Observación [-0.78924054  0.01523094]
# Accion 2460
# Observación [-0.57332677  0.02789052]
# Accion 2470
# Observación [-0.29659215  0.0240915 ]
# Accion 2480
# Observación [-0.1523688   0.00737257]
# Accion 2490
# Observación [-0.18562363 -0.01104573]
# Accion 2500
# Observación [-0.40411386 -0.03006266]
# Accion 2510
# Observación [-0.71092796 -0.02952347]
# Accion 2520
# Observación [-0.89868796 -0.00666635]
# Accion 2530
# Observación [-0.83836734  0.01560691]
# Accion 2540
# Observación [-0.5797762   0.03093672]
# Accion 2550
# Observación [-0.28635854  0.02499973]
# Accion 2560
# Observación [-0.14412989  0.00474888]
# Accion 2570
# Observación [-0.22989565 -0.01824876]
# Accion 2580
# Observación [-0.49731195 -0.03320986]
# Accion 2590
# Observación [-0.81311136 -0.02757039]
# Accion 2600
# Observación [-0.96320635 -0.00520016]
# Accion 2610
# Observación [-0.8705984   0.01739694]
# Accion 2620
# Observación [-0.58361137  0.03498854]
# Accion 2630
# Observación [-0.2647843   0.02761251]
# Accion 2640
# Observación [-0.09487896  0.00717178]
# Accion 2650
# Observación [-0.18419082 -0.02134647]
# Accion 2660
# Observación [-0.49714294 -0.03758732]
# Accion 2670
# Observación [-0.83494395 -0.02722451]
# Accion 2680
# Observación [-0.97832394 -0.00219905]
# Accion 2690
# Observación [-0.8609062   0.02047621]
# Accion 2700
# Observación [-0.5597052   0.03396251]
# Accion 2710
# Observación [-0.2450524   0.02587137]
# Accion 2720
# Observación [-0.10100515  0.00499134]
# Accion 2730
# Observación [-0.1728446  -0.01754239]
# Accion 2740
# Observación [-0.42694262 -0.02894551]
# Accion 2750
# Observación [-0.72622603 -0.02710922]
# Accion 2760
# Observación [-0.9042507  -0.01094888]
# Accion 2770
# Observación [-0.8641692   0.01492021]
# Accion 2780
# Observación [-0.5997958   0.03271708]
# Accion 2790
# Observación [-0.286214    0.02977569]
# Accion 2800
# Observación [-0.09484453  0.0066471 ]
# Accion 2810
# Observación [-0.1515917  -0.01724402]
# Accion 2820
# Observación [-0.42800143 -0.03232449]
# Accion 2830
# Observación [-0.7663973  -0.03109114]
# Accion 2840
# Observación [-0.9519465 -0.007863 ]
# Accion 2850
# Observación [-0.91111344  0.01412059]
# Accion 2860
# Observación [-0.6475693   0.03566922]
# Accion 2870
# Observación [-0.29361966  0.03292155]
# Accion 2880
# Observación [-0.08644128  0.01197543]
# Accion 2890
# Observación [-0.10298253 -0.01343345]
# Accion 2900
# Observación [-0.347131   -0.03271741]
# Accion 2910
# Observación [-0.6964561 -0.0329872]
# Accion 2920
# Observación [-0.9362127  -0.01390163]
# Accion 2930
# Observación [-0.9242018  0.0141096]
# Accion 2940
# Observación [-0.64852035  0.03804895]
# Accion 2950
# Observación [-0.27356178  0.03460344]
# Accion 2960
# Observación [-0.03135451  0.01247516]
# Accion 2970
# Observación [-0.07277696 -0.01843667]
# Accion 2980
# Observación [-0.36030796 -0.03493557]
# Accion 2990
# Observación [-0.7357248 -0.0344071]
# Accion 3000
# Observación [-0.97200185 -0.0148331 ]
# Accion 3010
# Observación [-0.998576    0.00892234]
# Accion 3020
# Observación [-0.81760603  0.02620047]
# Accion 3030
# Observación [-0.45542237  0.04006933]
# Accion 3040
# Observación [-0.13695098  0.02196595]
# Accion 3050
# Observación [-0.05594276 -0.00324423]
# Accion 3060
# Observación [-0.22677074 -0.03071434]
# Accion 3070
# Observación [-0.5962103 -0.04018  ]
# Accion 3080
# Observación [-0.91461056 -0.0217372 ]
# Accion 3090
# Observación [-0.9901716   0.00348139]
# Accion 3100
# Observación [-0.84069884  0.02610115]
# Accion 3110
# Observación [-0.5129907   0.03622612]
# Accion 3120
# Observación [-0.19531485  0.02490977]
# Accion 3130
# Observación [-0.05455081  0.00250949]
# Accion 3140
# Observación [-0.16660546 -0.01955038]
# Accion 3150
# Observación [-0.46169695 -0.03640516]
# Accion 3160
# Observación [-0.8186793  -0.03216397]
# Accion 3170
# Observación [-0.9919958  -0.00526876]
# Accion 3180
# Observación [-0.91362     0.01811314]
# Accion 3190
# Observación [-0.6434299   0.03110509]
# Accion 3200
# Observación [-0.30407307  0.03185565]
# Accion 3210
# Observación [-0.08706244  0.01325968]
# Accion 3220
# Observación [-0.09870956 -0.0111464 ]
# Accion 3230
# Observación [-0.32301286 -0.02998489]
# Accion 3240
# Observación [-0.65726256 -0.03164813]
# Accion 3250
# Observación [-0.88392    -0.01602697]
# Accion 3260
# Observación [-0.88400173  0.01381414]
# Accion 3270
# Observación [-0.6429471   0.03243489]
# Accion 3280
# Observación [-0.32272795  0.02827913]
# Accion 3290
# Observación [-0.1402437   0.00902902]
# Accion 3300
# Observación [-0.20948242 -0.01951202]
# Accion 3310
# Observación [-0.5038709 -0.0338482]
# Accion 3320
# Observación [-0.8032574  -0.02401282]
# Accion 3330
# Observación [-9.2679358e-01 -2.1803669e-04]
# Accion 3340
# Observación [-0.808893    0.02196487]
# Accion 3350
# Observación [-0.5209232   0.03241235]
# Accion 3360
# Observación [-0.2339993   0.02349909]
# Accion 3370
# Observación [-0.11492562  0.00153147]
# Accion 3380
# Observación [-0.23014651 -0.02094374]
# Accion 3390
# Observación [-0.5118693  -0.03324729]
# Accion 3400
# Observación [-0.7994512  -0.02219614]
# Accion 3410
# Observación [-0.90486616 -0.00103105]
# Accion 3420
# Observación [-0.8220806   0.01796487]
# Accion 3430
# Observación [-0.5441384   0.03165975]
# Accion 3440
# Observación [-0.26329646  0.02464189]
# Accion 3450
# Observación [-0.13528004  0.00151964]
# Accion 3460
# Observación [-0.225542   -0.02070869]
# Accion 3470
# Observación [-0.52255446 -0.03172866]
# Accion 3480
# Observación [-0.78698134 -0.02159804]
# Accion 3490
# Observación [-0.9280846  -0.00653792]
# Accion 3500
# Observación [-0.864306    0.01450416]
# Accion 3510
# Observación [-0.62969315  0.02907273]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 12
#      10     print("Observación", observation)
#      11 # Visualizar ejercicio
# ---> 12 env.render()
#      13 # Print del estado
#      14 # print(observation)
#      15 # Guarda en la variable action una de las acciones posibles elegida al azar
#      16 action = env.action_space.sample()
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:408, in OrderEnforcing.render(self)
#     403 if not self._disable_render_order_enforcing and not self._has_reset:
#     404     raise ResetNeeded(
#     405         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     406         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     407     )
# --> 408 return super().render()
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:302, in PassiveEnvChecker.render(self)
#     300     return env_render_passive_checker(self.env)
#     301 else:
# --> 302     return self.env.render()
#
# File c:\Users\detla\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:271, in MountainCarEnv.render(self)
#     269 if self.render_mode == "human":
#     270     pygame.event.pump()
# --> 271     self.clock.tick(self.metadata["render_fps"])
#     272     pygame.display.flip()
#     274 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
gym.__version__
# Out:
# '1.2.3'
