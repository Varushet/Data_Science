# %%
# %pip install streamlit
# %pip install plotly
# Out:
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    -------------------- ------------------- 4.7/9.2 MB 31.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 24.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/797.0 kB ? eta -:--:--
#    ---------------------------------------- 797.0/797.0 kB 6.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------------------------------- -- 10.5/11.3 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 33.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    ------------- -------------------------- 9.4/27.3 MB 45.2 MB/s eta 0:00:01
#    ------------------------------ --------- 21.0/27.3 MB 51.0 MB/s eta 0:00:01
#    ---------------------------------------  27.0/27.3 MB 50.4 MB/s eta 0:00:01
# ...
